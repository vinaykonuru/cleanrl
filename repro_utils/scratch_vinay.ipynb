# %%
import os
import numpy as np
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

# %%
events_path = '../runs/Hopper-v4_Group_Norm/Hopper-v4__ddpg_continuous_action__168__1714802504/events.out.tfevents.1714802504.della-i14g13.3542627.0'

# %%
from env_normalization import extract_scalar_from_event_file

res = extract_scalar_from_event_file(events_path)

# %%
res
# Out:
# [ScalarEvent(wall_time=1714802506.4271793, step=0, value=10.156810760498047),
#  ScalarEvent(wall_time=1714802506.896386, step=1000, value=8.644325256347656),
#  ScalarEvent(wall_time=1714802507.3601394, step=2000, value=8.708975791931152),
#  ScalarEvent(wall_time=1714802507.82721, step=3000, value=8.659707069396973),
#  ScalarEvent(wall_time=1714802508.321101, step=4000, value=10.795550346374512),
#  ScalarEvent(wall_time=1714802508.809376, step=5000, value=10.748830795288086),
#  ScalarEvent(wall_time=1714802509.2906363, step=6000, value=9.210928916931152),
#  ScalarEvent(wall_time=1714802509.7560549, step=7000, value=8.31959342956543),
#  ScalarEvent(wall_time=1714802510.2276878, step=8000, value=8.262449264526367),
#  ScalarEvent(wall_time=1714802510.7073667, step=9000, value=10.789793014526367),
#  ScalarEvent(wall_time=1714802511.1700737, step=10000, value=8.805288314819336),
#  ScalarEvent(wall_time=1714802511.6393023, step=11000, value=8.275842666625977),
# ...
